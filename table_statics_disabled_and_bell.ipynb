# %% [markdown]
# <a href="https://colab.research.google.com/github/cwave-dev/MODU/blob/main/table_statics_disabled_and_bell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install geopandas

from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import geopandas as gpd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
from shapely.geometry import Polygon, Point
import json

# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 694 kB/s
# ...
#      |████████████████████████████████| 6.3 MB 40.5 MB/s
# ...
# Mounted at /content/drive

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
# Out:
# Unknown system... sorry~~~~

# %%
df = pd.read_csv('/content/drive/MyDrive/데이터포럼/Toilet_Data/12_04_01_E_공중화장실정보_가공.csv')
print(df.head(5))
# Out:
#    mbd  msd  wnd bell
# 0    1    1    1    Y
# 1    1    0    1    Y
# 2    1    0    1    Y
# 3    1    1    1    Y
# 4    1    1    1    Y

# %%
mbd = 0
msd = 0
wnd = 0
bell = 0

for i in range(len(df['mbd'])):
    tmp = []
    if (df['mbd'][i] > 0):
        mbd = mbd + 1
    if (df['msd'][i] > 0):
        msd = msd + 1
    if (df['wnd'][i] > 0):
        wnd = wnd + 1
    if (df['bell'][i] == 'Y'):
        bell = bell + 1
    else:
      pass
# Out:
# 1585
# 876
# 1629
# 2248
# 5109
#    장애인 남성 대변기  장애인 남성 소변기  장애인 여성 대변기  안심벨 설치 여부
# 0   31.023684   17.146213   31.884909  44.000783

# %%
raw_data = {
            '장애인 남성 대변기': [(float) (mbd / len(df['mbd']) * 100)],
            '장애인 남성 소변기': [(float) (msd / len(df['mbd']) * 100)],
            '장애인 여성 대변기': [(float) (wnd / len(df['mbd']) * 100)]}

data = pd.DataFrame(raw_data)
data
# Out:
#    장애인 남성 대변기  장애인 남성 소변기  장애인 여성 대변기
# 0   31.023684   17.146213   31.884909

# %%
raw_data2 = {'안심벨 설치 여부': [(float) (bell / len(df['mbd']) * 100)]}

data2 = pd.DataFrame(raw_data2)
data2
# Out:
#    안심벨 설치 여부
# 0  44.000783
